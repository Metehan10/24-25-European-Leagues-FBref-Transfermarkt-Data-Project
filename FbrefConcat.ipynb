# %%
import pandas as pd

# %% [markdown]
# ## AdvancedGoalkeeping

# %%
# 📂 AdvancedGoalkeeping
BelcikaAdvancedGoalkeeping = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/BelcikaAdvancedGoalkeeping.xlsx")
BesBuyukLigAdvanceGoalkeeping = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/BesBuyukLigAdvanceGoalkeeping.xlsx")
HollandaAdvanceGoalkeeping = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/HollandaAdvanceGoalkeeping.xlsx")
IngiltereIkinciAdvancedGoalkeeping = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/IngiltereIkinciAdvancedGoalkeeping.xlsx")
PortekizAdvancedGoalkeeping = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/PortekizAdvancedGoalkeeping.xlsx")

# %%
birlesikAdvancedGoalkeeping = pd.concat([
    BelcikaAdvancedGoalkeeping,
    BesBuyukLigAdvanceGoalkeeping,
    HollandaAdvanceGoalkeeping,
    IngiltereIkinciAdvancedGoalkeeping,
    PortekizAdvancedGoalkeeping
], ignore_index=True)

# %%
birlesikAdvanceGoalkeeping
# Out:
#      Unnamed: 0   Rk            Player   Nation Pos           Squad     Age  \
# 0             0    1      Gavin Bazunu   ie IRL  GK  Standard Liège  23-089
# 1             1    2     Arnaud Bodart   be BEL  GK  Standard Liège  27-070
# 2             2    3       Sinan Bolat   tr TUR  GK        Westerlo  36-259
# 3             3    4   Colin Coosemans   be BEL  GK      Anderlecht  32-290
# 4             4    5        Jo Coppens   be BEL  GK    Sint-Truiden  34-150
# ..          ...  ...               ...      ...  ..             ...     ...
# 211         211  204        Danny Ward  wls WAL  GK  Leicester City  31-332
# 212         212  205      Timon Weiner   de GER  GK   Holstein Kiel  26-122
# 213         213  206     Robin Zentner   de GER  GK        Mainz 05  30-204
# 214         214  207  Michael Zetterer   de GER  GK   Werder Bremen  29-312
# 215         215  208      Melvin Zinga   fr FRA  GK          Angers  23-065
#
# ...

# %%
birlesikAdvanceGoalkeeping.to_excel('birlesikAdvanceGoalkeeping.xlsx')

# %% [markdown]
# ## Shooting

# %%
df1 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/BelcikaShooting.xlsx")
df2 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/BesBuyukLigShooting.xlsx")
df3 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/HollandaShooting.xlsx")
df4 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/IngiltereIkinciShooting.xlsx")
df5 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/PortekizShooting.xlsx")

shooting = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)
shooting.to_excel('birlesikShooting.xlsx')

# %% [markdown]
# ## Possession

# %%
df1 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/BelcikaPossession.xlsx")
df2 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/BesBuyukLigPossession.xlsx")
df3 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/HollandaPossession.xlsx")
df4 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/IngiltereIkinciPossession.xlsx")
df5 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/PortekizPossession.xlsx")

possession = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)
possession.to_excel('birlesikPossession.xlsx')

# %% [markdown]
# ## PlayingTime

# %%
df1 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/BelcikaPlayingTime.xlsx")
df2 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/BesBuyukLigPlayingTime.xlsx")
df3 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/HollandaPlayingTime.xlsx")
df4 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/IngiltereIkinciPlayingTime.xlsx")
df5 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/PortekizPlayingTime.xlsx")

playing_time = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)
playing_time.to_excel('birlesikPlaying_Time.xlsx')

# %% [markdown]
# ## PassingTypes

# %%
df1 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/BelcikaPassingTypes.xlsx")
df2 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/BesBuyukLigPassingTypes.xlsx")
df3 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/HollandaPassingTypes.xlsx")
df4 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/IngiltereIkinciPassingTypes.xlsx")
df5 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/PortekizPassingTypes.xlsx")

passing_types = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)
passing_types.to_excel('birlesikPassing_Types.xlsx')

# %% [markdown]
# ## Passing

# %%
df1 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/BelcikaPassing.xlsx")
df2 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/BesBuyukLigPassing.xlsx")
df3 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/HollandaPassing.xlsx")
df4 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/IngiltereIkinciPassing.xlsx")
df5 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/PortekizPassing.xlsx")

passing = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)
passing.to_excel('birlesikPassing.xlsx')

# %% [markdown]
# ## MiscellaneousStats

# %%
df1 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/BelcikaMiscellaneousStats.xlsx")
df2 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/BesBuyukLigMiscellaneousStats.xlsx")
df3 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/HollandaMiscellaneousStats.xlsx")
df4 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/IngiltereIkinciMiscellaneousStats.xlsx")
df5 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/PortekizMiscellaneousStats.xlsx")

misc = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)
misc.to_excel('birlesikMiscellaneousStats.xlsx')

# %% [markdown]
# ## Goalkeeping

# %%
df1 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/BelcikaGoalkeeping.xlsx")
df2 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/BesBuyukLigGoalkeeping.xlsx")
df3 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/HollandaGoalkeeping.xlsx")
df4 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/IngiltereIkinciGoalkeeping.xlsx")
df5 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/PortekizGoalkeeping.xlsx")

goalkeeping = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)
goalkeeping.to_excel('birlesikGoalkeeping.xlsx')

# %% [markdown]
# ## DefensiveActions

# %%
df1 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/BelcikaDefensiveActions.xlsx")
df2 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/BesBuyukLigDefensiveActions.xlsx")
df3 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/HollandaDefensiveActions.xlsx")
df4 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/IngiltereIkinciDefensiveActions.xlsx")
df5 = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneri/fbref/PortekizDefensiveActions.xlsx")

defensive = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)
defensive.to_excel('birlesikDefensiveActions.xlsx')
