# %% [markdown]
# ## Değer Adlarını uzun hale getirme

# %%
metrics = {
        'AdvancedGoalkeeping': {
            'GA': 'Goals Against',
            'PKA': 'Penalty Kicks Against',
            'FK': 'Free Kicks',
            'CK': 'Corner Kicks',
            'OG': 'Own Goals',
            'PSxG': 'Post-Shot Expected Goals',
            'PSxG/SoT': 'Post-Shot Expected Goals per Shot on Target',
            'PSxG+/-': 'Post-Shot Expected Goals Plus/Minus',
            '/90': 'Per 90 Minutes',
            'Cmp': 'Completions',
            'Att': 'Attempts',
            'Cmp%': 'Completion Percentage',
            'Att (GK)': 'Attempts (Goalkeeper)',
            'Thr': 'Throws',
            'Launch%': 'Launch Percentage',
            'AvgLen': 'Average Length',
            'Opp': 'Opponents',
            'Stp': 'Stops',
            'Stp%': 'Stop Percentage',
            '#OPA': 'Number of Offensive Actions',
            '#OPA/90': 'Number of Offensive Actions per 90',
            'AvgDist': 'Average Distance'
        },
        'DefensiveActions': {
            'Tkl': 'Tackles',
            'TklW': 'Tackles Won',
            'Def 3rd': 'Defensive Third',
            'Mid 3rd': 'Middle Third',
            'Att 3rd': 'Attacking Third',
            'Tkl,1': 'Tackles (1)',
            'Tkl%': 'Tackle Percentage',
            'Lost': 'Lost',
            'Blocks': 'Blocks',
            'Sh': 'Shots',
            'Pass': 'Passes',
            'Int': 'Interceptions',
            'Tkl+Int': 'Tackles + Interceptions',
            'Clr': 'Clearances',
            'Err': 'Errors'
        },
        'MiscellaneousStats': {
            'CrdY': 'Yellow Cards',
            'CrdR': 'Red Cards',
            '2CrdY': 'Second Yellow Cards',
            'Fls': 'Fouls',
            'Fld': 'Fouled',
            'Off': 'Offsides',
            'Crs': 'Crosses',
            'PKwon': 'Penalties Won',
            'PKcon': 'Penalties Conceded',
            'OG': 'Own Goals',
            'Recov': 'Recoveries',
            'Won': 'Won',
            'Lost': 'Lost',
            'Won%': 'Win Percentage'
        },
        'Passing': {
            'Cmp': 'Completions',
            'Att': 'Attempts',
            'Cmp%': 'Completion Percentage',
            'TotDist': 'Total Distance',
            'PrgDist': 'Progressive Distance',
            'Cmp,1': 'Completions (1)',
            'Att,1': 'Attempts (1)',
            'Cmp%,1': 'Completion Percentage (1)',
            'Cmp,2': 'Completions (2)',
            'Att,2': 'Attempts (2)',
            'Cmp%,2': 'Completion Percentage (2)',
            'Cmp,3': 'Completions (3)',
            'Att,3': 'Attempts (3)',
            'Cmp%,3': 'Completion Percentage (3)',
            'Ast': 'Assists',
            'xAG': 'Expected Assisted Goals',
            'xA': 'Expected Assists',
            'A-xAG': 'Assists minus Expected Assisted Goals',
            'KP': 'Key Passes',
            '1/3': 'Final Third',
            'PPA': 'Passes into Penalty Area',
            'CrsPA': 'Crosses into Penalty Area',
            'PrgP': 'Progressive Passes'
        },
        'PassingTypes': {
            'Att': 'Attempts',
            'Live': 'Live Ball',
            'Dead': 'Dead Ball',
            'FK': 'Free Kicks',
            'TB': 'Through Balls',
            'Sw': 'Switches',
            'Crs': 'Crosses',
            'TI': 'Throw-ins',
            'CK': 'Corner Kicks',
            'In': 'Inswinging',
            'Out': 'Outswinging',
            'Str': 'Straight',
            'Cmp': 'Completions',
            'Off': 'Offsides',
            'Blocks': 'Blocks'
        },
        'PlayingTime': {
            'MP': 'Matches Played',
            'Min': 'Minutes',
            'Mn/MP': 'Minutes per Match',
            'Min%': 'Minutes Percentage',
            '90s': '90s Played',
            'Starts': 'Starts',
            'Mn/Start': 'Minutes per Start',
            'Compl': 'Complete',
            'Subs': 'Substitutions',
            'Mn/Sub': 'Minutes per Substitution',
            'unSub': 'Unused Substitutions',
            'PPM': 'Points per Match',
            'onG': 'Goals On',
            'onGA': 'Goals Against On',
            '+/-': 'Plus/Minus',
            '+/-90': 'Plus/Minus per 90',
            'On-Off': 'On-Off',
            'onxG': 'Expected Goals On',
            'onxGA': 'Expected Goals Against On',
            'xG+/-': 'Expected Goals Plus/Minus',
            'xG+/-90': 'Expected Goals Plus/Minus per 90'
        },
        'Possession': {
            'Touches': 'Touches',
            'Def Pen': 'Defensive Penalty Area',
            'Def 3rd': 'Defensive Third',
            'Mid 3rd': 'Middle Third',
            'Att 3rd': 'Attacking Third',
            'Att Pen': 'Attacking Penalty Area',
            'Live': 'Live Ball',
            'Att': 'Attempts',
            'Succ': 'Successful',
            'Succ%': 'Success Percentage',
            'Tkld': 'Tackled',
            'Tkld%': 'Tackled Percentage',
            'Carries': 'Carries',
            'TotDist': 'Total Distance',
            'PrgDist': 'Progressive Distance',
            'PrgC': 'Progressive Carries',
            '1/3': 'Final Third',
            'CPA': 'Carries into Penalty Area',
            'Mis': 'Miscontrols',
            'Dis': 'Dispossessed',
            'Rec': 'Recoveries',
            'PrgR': 'Progressive Recoveries'
        },
        'Shooting': {
            'Gls': 'Goals',
            'Sh': 'Shots',
            'SoT': 'Shots on Target',
            'SoT%': 'Shots on Target Percentage',
            'Sh/90': 'Shots per 90',
            'SoT/90': 'Shots on Target per 90',
            'G/Sh': 'Goals per Shot',
            'G/SoT': 'Goals per Shot on Target',
            'Dist': 'Distance',
            'FK': 'Free Kicks',
            'PK': 'Penalty Kicks',
            'PKatt': 'Penalty Kick Attempts',
            'xG': 'Expected Goals',
            'npxG': 'Non-Penalty Expected Goals',
            'npxG/Sh': 'Non-Penalty Expected Goals per Shot',
            'G-xG': 'Goals minus Expected Goals',
            'np:G-xG': 'Non-Penalty Goals minus Expected Goals'
        }
    }

# %%
import pandas as pd

# %%
def flatten_metrics(metrics_dict):
    flat_dict = {}
    for group in metrics_dict.values():
        flat_dict.update(group)
    return flat_dict

value_mapping = flatten_metrics(metrics)

# %%
# Excel dosyasını oku (sayfa adı girmen gerekiyorsa sheet_name="Sayfa1" gibi ekle)
#df = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneriRevize/fbref/excel/Yeni klasör/AdvancedGoalkeeping.xlsx",sheet_name="RadarAdvancedGoalkeeping")

DefensiveActions = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneriRevize/fbref/excel/Yeni klasör/DefensiveActions.xlsx",sheet_name="RadarDefensiveActions")
DefensiveActions["Açıklama"] = DefensiveActions["Öznitelik"].map(value_mapping).fillna("Bilinmiyor")

# %%
MiscellaneousStats = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneriRevize/fbref/excel/Yeni klasör/MiscellaneousStats.xlsx",sheet_name="RadarMiscellaneousStats")
MiscellaneousStats["Açıklama"] = MiscellaneousStats["Öznitelik"].map(value_mapping).fillna("Bilinmiyor")

# %%
Passing = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneriRevize/fbref/excel/Yeni klasör/Passing.xlsx",sheet_name="RadarPassing")
Passing["Açıklama"] = Passing["Öznitelik"].map(value_mapping).fillna("Bilinmiyor")

# %%
PassingTypes = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneriRevize/fbref/excel/Yeni klasör/PassingTypes.xlsx",sheet_name="RadarPassingTypes")
PassingTypes["Açıklama"] = PassingTypes["Öznitelik"].map(value_mapping).fillna("Bilinmiyor")

# %%
PlayingTime = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneriRevize/fbref/excel/Yeni klasör/PlayingTime.xlsx",sheet_name="RadarPlayingTime")
PlayingTime["Açıklama"] = PlayingTime["Öznitelik"].map(value_mapping).fillna("Bilinmiyor")

# %%
Possession = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneriRevize/fbref/excel/Yeni klasör/Possession.xlsx",sheet_name="RadarPossession")
Possession["Açıklama"] = Possession["Öznitelik"].map(value_mapping).fillna("Bilinmiyor")

# %%
Shooting = pd.read_excel("C:/Users/user/Desktop/PROJELER/FutbolcuOneriRevize/fbref/excel/Yeni klasör/Shooting.xlsx",sheet_name="RadarShooting")
Shooting["Açıklama"] = Shooting["Öznitelik"].map(value_mapping).fillna("Bilinmiyor")

# %%
df
# Out:
#             Player Öznitelik  Değer                            Açıklama
# 0     Gavin Bazunu       90s   6.00                          90s Played
# 1     Gavin Bazunu        GA  12.00                       Goals Against
# 2     Gavin Bazunu       PKA   0.00               Penalty Kicks Against
# 3     Gavin Bazunu        FK   0.00                          Free Kicks
# 4     Gavin Bazunu        CK   1.00                        Corner Kicks
# ...            ...       ...    ...                                 ...
# 9908   Ivan Zlobin       Stp  16.00                               Stops
# 9909   Ivan Zlobin      Stp%   7.50                     Stop Percentage
# 9910   Ivan Zlobin      #OPA   7.00         Number of Offensive Actions
# 9911   Ivan Zlobin   #OPA/90   0.47  Number of Offensive Actions per 90
# 9912   Ivan Zlobin   AvgDist  10.60                    Average Distance
#
# [9913 rows x 4 columns]

# %%
df.to_excel('RadarAdvancedGoalkeepingGuncel.xlsx')

# %% [markdown]
# ## Veri Grubu Ekleyerek Değişken Adlarını Değiştirme

# %%
import pandas as pd

# %%
metrics = {
        'AdvancedGoalkeeping': {
            'GA': 'Goals Against',
            'PKA': 'Penalty Kicks Against',
            'FK': 'Free Kicks',
            'CK': 'Corner Kicks',
            'OG': 'Own Goals',
            'PSxG': 'Post-Shot Expected Goals',
            'PSxG/SoT': 'Post-Shot Expected Goals per Shot on Target',
            'PSxG+/-': 'Post-Shot Expected Goals Plus/Minus',
            '/90': 'Per 90 Minutes',
            'Cmp': 'Completions',
            'Att': 'Attempts',
            'Cmp%': 'Completion Percentage',
            'Att (GK)': 'Attempts (Goalkeeper)',
            'Thr': 'Throws',
            'Launch%': 'Launch Percentage',
            'AvgLen': 'Average Length',
            'Opp': 'Opponents',
            'Stp': 'Stops',
            'Stp%': 'Stop Percentage',
            '#OPA': 'Number of Offensive Actions',
            '#OPA/90': 'Number of Offensive Actions per 90',
            'AvgDist': 'Average Distance'
        },
        'DefensiveActions': {
            'Tkl': 'Tackles',
            'TklW': 'Tackles Won',
            'Def 3rd': 'Defensive Third',
            'Mid 3rd': 'Middle Third',
            'Att 3rd': 'Attacking Third',
            'Tkl,1': 'Tackles (1)',
            'Tkl%': 'Tackle Percentage',
            'Lost': 'Lost',
            'Blocks': 'Blocks',
            'Sh': 'Shots',
            'Pass': 'Passes',
            'Int': 'Interceptions',
            'Tkl+Int': 'Tackles + Interceptions',
            'Clr': 'Clearances',
            'Err': 'Errors'
        },
        'MiscellaneousStats': {
            'CrdY': 'Yellow Cards',
            'CrdR': 'Red Cards',
            '2CrdY': 'Second Yellow Cards',
            'Fls': 'Fouls',
            'Fld': 'Fouled',
            'Off': 'Offsides',
            'Crs': 'Crosses',
            'PKwon': 'Penalties Won',
            'PKcon': 'Penalties Conceded',
            'OG': 'Own Goals',
            'Recov': 'Recoveries',
            'Won': 'Won',
            'Lost': 'Lost',
            'Won%': 'Win Percentage'
        },
        'Passing': {
            'Cmp': 'Completions',
            'Att': 'Attempts',
            'Cmp%': 'Completion Percentage',
            'TotDist': 'Total Distance',
            'PrgDist': 'Progressive Distance',
            'Cmp,1': 'Completions (1)',
            'Att,1': 'Attempts (1)',
            'Cmp%,1': 'Completion Percentage (1)',
            'Cmp,2': 'Completions (2)',
            'Att,2': 'Attempts (2)',
            'Cmp%,2': 'Completion Percentage (2)',
            'Cmp,3': 'Completions (3)',
            'Att,3': 'Attempts (3)',
            'Cmp%,3': 'Completion Percentage (3)',
            'Ast': 'Assists',
            'xAG': 'Expected Assisted Goals',
            'xA': 'Expected Assists',
            'A-xAG': 'Assists minus Expected Assisted Goals',
            'KP': 'Key Passes',
            '1/3': 'Final Third',
            'PPA': 'Passes into Penalty Area',
            'CrsPA': 'Crosses into Penalty Area',
            'PrgP': 'Progressive Passes'
        },
        'PassingTypes': {
            'Att': 'Attempts',
            'Live': 'Live Ball',
            'Dead': 'Dead Ball',
            'FK': 'Free Kicks',
            'TB': 'Through Balls',
            'Sw': 'Switches',
            'Crs': 'Crosses',
            'TI': 'Throw-ins',
            'CK': 'Corner Kicks',
            'In': 'Inswinging',
            'Out': 'Outswinging',
            'Str': 'Straight',
            'Cmp': 'Completions',
            'Off': 'Offsides',
            'Blocks': 'Blocks'
        },
        'PlayingTime': {
            'MP': 'Matches Played',
            'Min': 'Minutes',
            'Mn/MP': 'Minutes per Match',
            'Min%': 'Minutes Percentage',
            '90s': '90s Played',
            'Starts': 'Starts',
            'Mn/Start': 'Minutes per Start',
            'Compl': 'Complete',
            'Subs': 'Substitutions',
            'Mn/Sub': 'Minutes per Substitution',
            'unSub': 'Unused Substitutions',
            'PPM': 'Points per Match',
            'onG': 'Goals On',
            'onGA': 'Goals Against On',
            '+/-': 'Plus/Minus',
            '+/-90': 'Plus/Minus per 90',
            'On-Off': 'On-Off',
            'onxG': 'Expected Goals On',
            'onxGA': 'Expected Goals Against On',
            'xG+/-': 'Expected Goals Plus/Minus',
            'xG+/-90': 'Expected Goals Plus/Minus per 90'
        },
        'Possession': {
            'Touches': 'Touches',
            'Def Pen': 'Defensive Penalty Area',
            'Def 3rd': 'Defensive Third',
            'Mid 3rd': 'Middle Third',
            'Att 3rd': 'Attacking Third',
            'Att Pen': 'Attacking Penalty Area',
            'Live': 'Live Ball',
            'Att': 'Attempts',
            'Succ': 'Successful',
            'Succ%': 'Success Percentage',
            'Tkld': 'Tackled',
            'Tkld%': 'Tackled Percentage',
            'Carries': 'Carries',
            'TotDist': 'Total Distance',
            'PrgDist': 'Progressive Distance',
            'PrgC': 'Progressive Carries',
            '1/3': 'Final Third',
            'CPA': 'Carries into Penalty Area',
            'Mis': 'Miscontrols',
            'Dis': 'Dispossessed',
            'Rec': 'Recoveries',
            'PrgR': 'Progressive Recoveries'
        },
        'Shooting': {
            'Gls': 'Goals',
            'Sh': 'Shots',
            'SoT': 'Shots on Target',
            'SoT%': 'Shots on Target Percentage',
            'Sh/90': 'Shots per 90',
            'SoT/90': 'Shots on Target per 90',
            'G/Sh': 'Goals per Shot',
            'G/SoT': 'Goals per Shot on Target',
            'Dist': 'Distance',
            'FK': 'Free Kicks',
            'PK': 'Penalty Kicks',
            'PKatt': 'Penalty Kick Attempts',
            'xG': 'Expected Goals',
            'npxG': 'Non-Penalty Expected Goals',
            'npxG/Sh': 'Non-Penalty Expected Goals per Shot',
            'G-xG': 'Goals minus Expected Goals',
            'np:G-xG': 'Non-Penalty Goals minus Expected Goals'
        }
    }

# %%
# flatten_metrics fonksiyonu – kolon değerlerini açıklamalı hale getirmek
def flatten_metrics(metrics_dict):
    flat_dict = {}
    for group in metrics_dict.values():
        flat_dict.update(group)
    return flat_dict

value_mapping = flatten_metrics(metrics)

# %%
# Radar veri dosyaları
files_info = {
    "AdvancedGoalkeeping":"RadarAdvancedGoalkeeping",
    "DefensiveActions": "RadarDefensiveActions",
    "MiscellaneousStats": "RadarMiscellaneousStats",
    "Passing": "RadarPassing",
    "PassingTypes":"RadarPassingTypes",
    "PlayingTime": "RadarPlayingTime",
    "Possession": "RadarPossession",
    "Shooting": "RadarShooting"
}

# %%
# Klasör yolu
base_path = "C:/Users/user/Desktop/PROJELER/FutbolcuOneriRevize/fbref/excel/Yeni klasör/"

# %%
# Her veri için oku, açıklamayı ekle, kaynak ismini ekle
all_data = []

for data_type, sheet_name in files_info.items():
    path = f"{base_path}{data_type}.xlsx"
    df = pd.read_excel(path, sheet_name=sheet_name)
    
    # Açıklama kolonunu ekle
    df["Uzun"] = df["Öznitelik"].map(value_mapping).fillna("Bilinmiyor")
    
    # Hangi veri grubundan geldiğini belirten bir kolon ekle
    df["VeriGrubu"] = data_type
    
    all_data.append(df)

# %%
df
# Out:
#                 Player Öznitelik  Değer  \
# 0      Ahmed Abdullahi       90s    0.0
# 1      Ahmed Abdullahi       Gls    0.0
# 2      Ahmed Abdullahi        Sh    0.0
# 3      Ahmed Abdullahi       SoT    0.0
# 4      Ahmed Abdullahi     Sh/90    0.0
# ...                ...       ...    ...
# 88395   Nermin Zolotić     PKatt    0.0
# 88396   Nermin Zolotić        xG    0.0
# 88397   Nermin Zolotić      npxG    0.0
# 88398   Nermin Zolotić      G-xG    0.0
# 88399   Nermin Zolotić   np:G-xG    0.0
#
#                                      Açıklama  \
# 0                                  90s Played
# 1                                       Goals
# 2                                       Shots
# 3                             Shots on Target
# 4                                Shots per 90
# ...                                       ...
# 88395                   Penalty Kick Attempts
# 88396                          Expected Goals
# 88397              Non-Penalty Expected Goals
# ...

# %%
# Hepsini tek bir DataFrame’de birleştir
merged_df = pd.concat(all_data, ignore_index=True)

# %%
# Sonuç dosyasını kaydet
output_path = f"{base_path}Radar_Tek_Tablosu.xlsx"
merged_df.to_excel(output_path, index=False)
